# %%
from pytube import YouTube

# Download video subtitles or description
def get_video_info(url):
    yt = YouTube('https://www.youtube.com/watch?v=9Is-ZFd1LFE&ab_channel=DriftDeeper')
    if yt.captions:
        captions = yt.captions.get_by_language_code('en')
        print(captions)
        return captions.generate_srt_captions() if captions else yt.description
    else:
        print(yt.description)
        return yt.description
